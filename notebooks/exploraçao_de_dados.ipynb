# %%
import pandas as pd

# %%
df= pd.read_csv(r'C:\Users\Pedro\Documents\GitHub\analise-criminalidade-rj\data\raw\BaseDPEvolucaoMensalCisp.csv', encoding= 'latin1', sep= ';')

# %%
df.columns

# %%
df
